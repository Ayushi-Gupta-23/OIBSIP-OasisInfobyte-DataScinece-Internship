# %% [markdown]
# # Iris classification :-
#
# ## Project Objective:
# ### The main objective of this project is to develop a machine learning model that can accurately classify Iris flowers into their respective species based on various characteristics.
#
# ## Dataset:
# ### The Iris dataset is commonly used for this project. It consists of 150 samples from each of three species of Iris flowers (Iris setosa, Iris virginica, and Iris versicolor). For each sample, four features are measured:
#
# #### Sepal Length (in centimeters)
# #### Sepal Width (in centimeters)
# #### Petal Length (in centimeters)
# #### Petal Width (in centimeters)

# %% [markdown]
# ### Importing header files:-

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Reading the dataset

# %%
df=pd.read_csv("C:/Users/ayush/OneDrive/Desktop/Data sc/datasets/Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Filtering the dataset

# %%
df.drop('Id',axis=1)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 6)

# %%
df.Species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ### Visualising the data

# %%
import matplotlib.pyplot as plt
# Calculate the value counts
value_counts = df['Species'].value_counts()

# Create a bar plot
plt.figure(figsize=(8, 6))
value_counts.plot(kind='bar', color='skyblue')
plt.title('Label Distribution')
plt.xlabel('Label')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Create a pie chart
plt.figure(figsize=(4, 4))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen','lightblue'])
plt.title('Label Distribution')
plt.show()

# %%
y = df.iloc[0:150, 4].values
y = np.where(y == 'Iris-setosa', -1, 2)
X = df.iloc[0:150, [0, 3]].values
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_16856\2494662112.py:2: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   y = np.where(y == 'Iris-setosa', -1, 2)

# %%
plt.scatter(X[:50, 0], X[:50, 1], color='red', marker='o', label='setosa')
plt.scatter(X[50:100,0], X[50:100,1], color='blue', marker='x', label='versicolor')
plt.scatter(X[100:150,0], X[100:150,1], color='green', marker='+', label='virginica')
plt.xlabel('sepal length [cm]')
plt.ylabel('petal length [cm]')
plt.legend(loc='upper left')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm',hue='Species', data=df, )

# Placing Legend outside the Figure
plt.legend(bbox_to_anchor=(1, 1), loc=2)

plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,10))

axes[0,0].set_title("Sepal Length")
axes[0,0].hist(df['SepalLengthCm'], bins=7)

axes[0,1].set_title("Sepal Width")
axes[0,1].hist(df['SepalWidthCm'], bins=5);

axes[1,0].set_title("Petal Length")
axes[1,0].hist(df['PetalLengthCm'], bins=6);

axes[1,1].set_title("Petal Width")
axes[1,1].hist(df['PetalWidthCm'], bins=6);

# %%
# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(6, 4))

# Plot the distribution plots for each feature
sns.distplot(df[df['Species'] == 'Iris-setosa']['SepalLengthCm'], ax=axes[0, 0], label='Iris-setosa')
sns.distplot(df[df['Species'] == 'Iris-versicolor']['SepalLengthCm'], ax=axes[0, 0], label='Iris-versicolor')
sns.distplot(df[df['Species'] == 'Iris-virginica']['SepalLengthCm'], ax=axes[0, 0], label='Iris-virginica')
axes[0, 0].set_title("Sepal Length")

sns.distplot(df[df['Species'] == 'Iris-setosa']['SepalWidthCm'], ax=axes[0, 1], label='Iris-setosa')
sns.distplot(df[df['Species'] == 'Iris-versicolor']['SepalWidthCm'], ax=axes[0, 1], label='Iris-versicolor')
sns.distplot(df[df['Species'] == 'Iris-virginica']['SepalWidthCm'], ax=axes[0, 1], label='Iris-virginica')
axes[0, 1].set_title("Sepal Width")

sns.distplot(df[df['Species'] == 'Iris-setosa']['PetalLengthCm'], ax=axes[1, 0], label='Iris-setosa')
sns.distplot(df[df['Species'] == 'Iris-versicolor']['PetalLengthCm'], ax=axes[1, 0], label='Iris-versicolor')
sns.distplot(df[df['Species'] == 'Iris-virginica']['PetalLengthCm'], ax=axes[1, 0], label='Iris-virginica')
axes[1, 0].set_title("Petal Length")

sns.distplot(df[df['Species'] == 'Iris-setosa']['PetalWidthCm'], ax=axes[1, 1], label='Iris-setosa')
sns.distplot(df[df['Species'] == 'Iris-versicolor']['PetalWidthCm'], ax=axes[1, 1], label='Iris-versicolor')
sns.distplot(df[df['Species'] == 'Iris-virginica']['PetalWidthCm'], ax=axes[1, 1], label='Iris-virginica')
axes[1, 1].set_title("Petal Width")

# Add legends
#axes[0, 0].legend()
#axes[0, 1].legend()
axes[1, 0].legend()
axes[1, 1].legend()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_16856\1510641326.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Species'] == 'Iris-setosa']['SepalLengthCm'], ax=axes[0, 0], label='Iris-setosa')
# C:\Users\ayush\AppData\Local\Temp\ipykernel_16856\1510641326.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df.corr(method='pearson')
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_16856\1928163937.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson')
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Box plot for Sepal Length
sns.boxplot(x='Species', y='SepalLengthCm', data=df, ax=axes[0, 0])
axes[0, 0].set_title('Sepal Length')

# Box plot for Sepal Width
sns.boxplot(x='Species', y='SepalWidthCm', data=df, ax=axes[0, 1])
axes[0, 1].set_title('Sepal Width')

# Box plot for Petal Length
sns.boxplot(x='Species', y='PetalLengthCm', data=df, ax=axes[1, 0])
axes[1, 0].set_title('Petal Length')

# Box plot for Petal Width
sns.boxplot(x='Species', y='PetalWidthCm', data=df, ax=axes[1, 1])
axes[1, 1].set_title('Petal Width')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### Training the model
#
# ### Logistic Regression can perform well with the linear dataset.
# ### It works by modeling the probability of each class, and if the decision boundaries between classes are mostly linear, Logistic Regression can provide accurate results.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression  # Example model

# Load your dataset (assuming 'df' contains your dataset)
# Replace 'features' and 'target' with the appropriate column names
X = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = df['Species']

# Split the data into training and testing sets (e.g., 70% training, 30% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Data preprocessing: Standardize the feature values (optional but often beneficial)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Choose a machine learning algorithm (e.g., Logistic Regression as an example)
model = LogisticRegression(random_state=42)

# Train the model on the training data
model.fit(X_train, y_train)

# Evaluate the model on the testing data
accuracy = model.score(X_test, y_test)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 1.00

# %%
y_pred = model.predict(X_test)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred)
plt.xlabel("True Labels (y_test)")
plt.ylabel("Predicted Labels (y_pred)")
plt.title("True vs. Predicted Labels")
plt.show()

# %%
# Create an array of indices for the data points
indices = np.arange(len(y_test))

# Create a line plot with separate y-axes
fig, ax1 = plt.subplots(figsize=(8, 6))
color = 'tab:blue'
ax1.set_xlabel("Data Point Index")
ax1.set_ylabel("True Labels", color=color)
ax1.plot(indices, y_test, marker='o', linestyle='-', color=color, label='True Labels')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # Create a second y-axis that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel("Predicted Labels", color=color)
ax2.plot(indices, y_pred, marker='o', linestyle='-', color=color, label='Predicted Labels')
ax2.tick_params(axis='y', labelcolor=color)

plt.title("True vs. Predicted Labels (Line Graph with Separate Y-Axes)")
fig.tight_layout()
plt.show()

# %%
# Visualize the model's predictions
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, c='blue', marker='o', alpha=0.7, label='Actual vs. Predicted')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', linewidth=2, label='Perfect Fit')
plt.xlabel("Actual ")
plt.ylabel("Predicted ")
plt.title("Actual vs. Predicted")
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ### The graph clearly depicts that the model is trained with accuracy one as the red dotted line is touching all the blue points perfectly.
